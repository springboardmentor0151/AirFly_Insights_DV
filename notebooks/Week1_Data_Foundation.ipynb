# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/flights.csv")

df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# 0      1400     5      15  2013-01-01 05:00:00   United Air Lines Inc.
# 1      1416     5      29  2013-01-01 05:00:00   United Air Lines Inc.
# 2      1089     5      40  2013-01-01 05:00:00  American Airlines Inc.
# 3      1576     5      45  2013-01-01 05:00:00         JetBlue Airways
# 4       762     6       0  2013-01-01 06:00:00    Delta Air Lines Inc.
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (336776, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              336776 non-null  int64
#  1   year            336776 non-null  int64
#  2   month           336776 non-null  int64
#  3   day             336776 non-null  int64
#  4   dep_time        328521 non-null  float64
#  5   sched_dep_time  336776 non-null  int64
#  6   dep_delay       328521 non-null  float64
#  7   arr_time        328063 non-null  float64
#  8   sched_arr_time  336776 non-null  int64
#  9   arr_delay       327346 non-null  float64
#  10  carrier         336776 non-null  object
#  11  flight          336776 non-null  int64
#  12  tailnum         334264 non-null  object
#  13  origin          336776 non-null  object
#  14  dest            336776 non-null  object
#  15  air_time        327346 non-null  float64
#  16  distance        336776 non-null  int64
#  17  hour            336776 non-null  int64
#  18  minute          336776 non-null  int64
#  19  time_hour       336776 non-null  object
#  20  name            336776 non-null  object
# dtypes: float64(5), int64(10), object(6)
# memory usage: 54.0+ MB

# %%
df.isnull().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %%
df_sample = df.sample(100000, random_state=42)
df_sample.shape
# Out:
# (100000, 23)

# %%
categorical_cols = ['carrier', 'origin', 'dest', 'name']

for col in categorical_cols:
    df[col] = df[col].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336776 entries, 0 to 336775
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               336776 non-null  int64
#  1   year             336776 non-null  int64
#  2   month            336776 non-null  int64
#  3   day              336776 non-null  int64
#  4   dep_time         328521 non-null  float64
#  5   sched_dep_time   336776 non-null  int64
#  6   dep_delay        328521 non-null  float64
#  7   arr_time         328063 non-null  float64
#  8   sched_arr_time   336776 non-null  int64
#  9   arr_delay        327346 non-null  float64
#  10  carrier          336776 non-null  category
#  11  flight           336776 non-null  int64
#  12  tailnum          334264 non-null  object
#  13  origin           336776 non-null  category
#  14  dest             336776 non-null  category
#  15  air_time         327346 non-null  float64
#  16  distance         336776 non-null  int64
#  17  hour             336776 non-null  int64
#  18  minute           336776 non-null  int64
#  19  time_hour        336776 non-null  object
#  20  name             336776 non-null  category
#  21  is_cancelled     336776 non-null  bool
#  22  arrival_missing  336776 non-null  bool
# dtypes: bool(2), category(4), float64(5), int64(10), object(2)
# memory usage: 45.6+ MB

# %%
df[['dep_delay','arr_delay']].isnull().sum()
# Out:
# dep_delay    8255
# arr_delay    9430
# dtype: int64

# %%
df['is_cancelled'] = df['dep_time'].isnull()

# %%
df['date'] = pd.to_datetime(df[['year','month','day']])

# %%
df['month_name'] = df['date'].dt.month_name()

# %%
df['day_of_week'] = df['date'].dt.day_name()

# %%
df['hour'] = df['sched_dep_time'] // 100
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... hour  minute            time_hour  \
# 0             819       11.0  ...    5      15  2013-01-01 05:00:00
# 1             830       20.0  ...    5      29  2013-01-01 05:00:00
# 2             850       33.0  ...    5      40  2013-01-01 05:00:00
# 3            1022      -18.0  ...    5      45  2013-01-01 05:00:00
# 4             837      -25.0  ...    6       0  2013-01-01 06:00:00
#
#                      name is_cancelled  arrival_missing       date  \
# 0   United Air Lines Inc.        False            False 2013-01-01
# 1   United Air Lines Inc.        False            False 2013-01-01
# 2  American Airlines Inc.        False            False 2013-01-01
# 3         JetBlue Airways        False            False 2013-01-01
# 4    Delta Air Lines Inc.        False            False 2013-01-01
#
#    month_name  day_of_week    route
# 0     January      Tuesday  EWR-IAH
# 1     January      Tuesday  LGA-IAH
# 2     January      Tuesday  JFK-MIA
# 3     January      Tuesday  JFK-BQN
# 4     January      Tuesday  LGA-ATL
#
# [5 rows x 27 columns]

# %%
df['route'] = df['origin'].astype(str) + "-" + df['dest'].astype(str)
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... hour  minute            time_hour  \
# 0             819       11.0  ...    5      15  2013-01-01 05:00:00
# 1             830       20.0  ...    5      29  2013-01-01 05:00:00
# 2             850       33.0  ...    5      40  2013-01-01 05:00:00
# 3            1022      -18.0  ...    5      45  2013-01-01 05:00:00
# 4             837      -25.0  ...    6       0  2013-01-01 06:00:00
#
#                      name is_cancelled  arrival_missing       date  \
# 0   United Air Lines Inc.        False            False 2013-01-01
# 1   United Air Lines Inc.        False            False 2013-01-01
# 2  American Airlines Inc.        False            False 2013-01-01
# 3         JetBlue Airways        False            False 2013-01-01
# 4    Delta Air Lines Inc.        False            False 2013-01-01
#
#    month_name  day_of_week    route
# 0     January      Tuesday  EWR-IAH
# 1     January      Tuesday  LGA-IAH
# 2     January      Tuesday  JFK-MIA
# 3     January      Tuesday  JFK-BQN
# 4     January      Tuesday  LGA-ATL
#
# [5 rows x 27 columns]

# %%
df[['origin','dest','route']].head()
# Out:
#   origin dest    route
# 0    EWR  IAH  EWR-IAH
# 1    LGA  IAH  LGA-IAH
# 2    JFK  MIA  JFK-MIA
# 3    JFK  BQN  JFK-BQN
# 4    LGA  ATL  LGA-ATL

# %%
df['is_delayed'] = df['dep_delay'] > 15

# %%
df['is_weekend'] = df['day_of_week'].isin(['Saturday','Sunday'])
#weekend flag to analyze delay differences between weekdays and weekends.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv("../data/flights_cleaned_m1.csv", index=False)
