# %% [markdown]
# # Week 1 - Data Foundation and Initial Exploration
#
# ## Dataset Overview
# - Loaded 200,000 sample rows for analysis.
# - Dataset contains 12 columns.
# - No missing values detected.
# - Data types reviewed and validated.
#
# ## Observations
# - Majority columns are categorical (object type).
# - Numerical columns include duration, days_left, and price.
# - Dataset is clean and ready for preprocessing in Week 2.

# %%
import pandas as pd

df = pd.read_csv("../data/flights.csv", nrows=200000)

df.head()

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
df.info()
